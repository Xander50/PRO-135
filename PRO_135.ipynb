# %% [markdown]
# <a href="https://colab.research.google.com/github/Xander50/PRO-135/blob/main/PRO_135.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/procodingclass/PRO-Stars-Dataset-CSVs
# Out:
# Cloning into 'PRO-Stars-Dataset-CSVs'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 26 (delta 10), reused 12 (delta 5), pack-reused 0
# Unpacking objects: 100% (26/26), 27.75 KiB | 1.98 MiB/s, done.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("/content/PRO-Stars-Dataset-CSVs/filtered_stars.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       Star_name   Distance  Mass  Radius  \
# 0             0           0             Sun   0.000016   1.0    1.00
# 1             1           1          Sirius   8.600000   2.1    1.71
# 2             2           3  Alpha Centauri   4.400000   1.1    1.20
# 3             3          12          Altair  17.000000   1.8    1.80
# 4             4          18       Fomalhaut  25.000000   1.9    1.80
#
#       Gravity
# 0  274.269161
# 1  196.971800
# 2  209.511165
# 3  152.371756
# 4  160.836854

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Star_name', 'Distance', 'Mass', 'Radius',
#        'Gravity'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0.1', 'Unnamed: 0'],axis=1,inplace=True)

# %%
name=df["Star_name"].to_list()
mass=df["Mass"].to_list()
radius=df["Radius"].to_list()
gravity=df["Gravity"].to_list()
dist=df["Distance"].to_list()

plt.figure(figsize=(10,5))
plt.title("stars solar mass")
plt.bar(name[0:9],mass[0:9])
# Out:
# <BarContainer object of 9 artists>

# %%
plt.figure(figsize=(10,5))
plt.title("stars solar radius")
plt.bar(name[0:9],radius[0:9])
# Out:
# <BarContainer object of 9 artists>

# %%
plt.figure(figsize=(10,5))
plt.title("stars solar gravity")
plt.bar(name[0:9],gravity[0:9])
# Out:
# <BarContainer object of 9 artists>

# %%
plt.figure(figsize=(10,5))
plt.title("stars solar distance")
plt.bar(name[0:9],dist[0:9])
# Out:
# <BarContainer object of 9 artists>
